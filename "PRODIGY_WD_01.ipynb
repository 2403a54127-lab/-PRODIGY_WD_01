# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a54127-lab/-PRODIGY_WD_01/blob/main/%22PRODIGY_WD_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Dataset
df = pd.read_csv("/content/world_population_sample.csv")

# Select Top 10 Countries by 2022 Population
top10 = df.sort_values(
    by="2022 Population",
    ascending=False
).head(10)

# Create Bar Chart
plt.figure(figsize=(12,6))

plt.bar(
    top10["Country/Territory"],
    top10["2022 Population"],
    color="skyblue",
    edgecolor="black"
)

plt.title("Top 10 Countries by Population (2022)")
plt.xlabel("Country")
plt.ylabel("Population")

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/world_population_sample.csv")

plt.figure(figsize=(10,6))

plt.hist(
    df["2022 Population"],
    bins=20,
    color="lightgreen",
    edgecolor="black"
)

plt.title("Distribution of Population (2022)")
plt.xlabel("Population")
plt.ylabel("Number of Countries")

plt.show()
